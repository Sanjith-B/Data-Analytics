# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
dataset_path = globals().get("dataset_path")
output_results_path = globals().get("output_results_path")

# %%
full_df = pd.read_csv(dataset_path)

# %%
#full_df = pd.read_csv('/content/drive/MyDrive/Demand Forecasting (Prince Pharma)/Engineered Data/Location Data/California_-_Loc_1_unitsales.csv')

del full_df['ABC_XYZ']
del full_df['Monthwise_SUR']
del full_df['avg_SUR']
del full_df['Quarterly_SUR']
del full_df['ITEMNUMBER']
del full_df['QTY']
del full_df['Revenue']
del full_df['year-month']

# %%
full_df['date_of_sale'] = pd.to_datetime(full_df['date_of_sale'], format="%Y-%m-%d")
full_df['year'] = full_df['date_of_sale'].dt.year
full_df['month'] = full_df['date_of_sale'].dt.month
full_df['quarter'] = full_df['date_of_sale'].dt.quarter

# %%
months_count = full_df.groupby(['item_id'])['date_of_sale'].count().reset_index()
avg_months_count = int(months_count['date_of_sale'].mean())  # Convert mean to integer
avg_months_count

full_df['Monthwise_SUR'] = (full_df['qty_sold'] / (full_df['available_stock'] + full_df['qty_sold'])) * 100
full_df['Monthwise_SUR'] = full_df['Monthwise_SUR'].fillna(0)
months_count = full_df.groupby('item_id')['date_of_sale'].count().reset_index()
months_count = months_count.rename(columns={'date_of_sale': 'months_count'})
avg_utilisation = full_df.groupby('item_id')['Monthwise_SUR'].sum().reset_index()
avg_utilisation = avg_utilisation.merge(months_count, on='item_id', how='left')
avg_utilisation['Avg_Utilisation'] = avg_utilisation['Monthwise_SUR'] / avg_utilisation['months_count']

full_df = full_df.merge(avg_utilisation[['item_id', 'Avg_Utilisation']], on='item_id', how='left')

quarterly_sur = (
    full_df.groupby(['item_id', 'quarter'])['Monthwise_SUR']
    .mean()
    .reset_index()
    .rename(columns={'Monthwise_SUR': 'Quarterly_SUR'})
)
full_df = full_df.merge(quarterly_sur, on=['item_id', 'quarter'], how='left')


full_df = full_df.sort_values(by=['item_id', 'date_of_sale'])

full_df['prev_available_stock'] = full_df.groupby('item_id')['available_stock'].shift(1)
full_df['prev_available_stock'].fillna(method='bfill', inplace=True)  # Use next available value

full_df['prev_qty_sold'] = full_df.groupby('item_id')['qty_sold'].shift(1)
full_df['prev_qty_sold'].fillna(0, inplace=True)  # Default to 0 if missing


# Calculate stock reduction percentage
full_df['stock_reduction'] = np.where(
    full_df['prev_available_stock'] > 0,
    ((full_df['prev_available_stock'] - full_df['available_stock']) / full_df['prev_available_stock']) * 100,
    0  # If previous stock is 0, assume no reduction
)


# Create Stockout Flag (1 if stockout, 0 otherwise)
full_df['stockout_flag'] = ((full_df['available_stock'] == 0) |
                            ((full_df['stock_reduction'] > 50) & (full_df['Monthwise_SUR'] >= 95))).astype(int)
full_df['stockout_flag'].value_counts()
# Out:
# stockout_flag
# 0    47007
# 1     1953
# Name: count, dtype: int64

# %% [markdown]
# Demand Estimation Trials

# %%
import numpy as np
import pandas as pd

# Sort data to maintain sequential logic
full_df = full_df.sort_values(by=['item_id', 'date_of_sale'])

# Rolling averages for historical demand trends
full_df['rolling_QTY_3M'] = full_df.groupby('item_id')['qty_sold'].rolling(window=3, min_periods=1).mean().reset_index(level=0, drop=True)
full_df['rolling_QTY_6M'] = full_df.groupby('item_id')['qty_sold'].rolling(window=6, min_periods=1).mean().reset_index(level=0, drop=True)
full_df['rolling_QTY_12M'] = full_df.groupby('item_id')['qty_sold'].rolling(window=12, min_periods=1).mean().reset_index(level=0, drop=True)

# Default estimated demand = qty_sold
full_df['est_demand'] = full_df['qty_sold']

# ---- Case 1: Adjust demand when stock < qty_sold ----
def adjust_demand(group):
    mask = (group['available_stock'] < group['qty_sold']) & (group['available_stock'] > 0)
    for idx in group[mask].index:
        prev_valid_rows = group.loc[
            (group['date_of_sale'] < group.loc[idx, 'date_of_sale']) &
            (group['qty_sold'] != 0) &
            (group['available_stock'] >= group['qty_sold']) &
            (group['qty_sold'] > group.loc[idx, 'qty_sold'])
        ].sort_values(by='date_of_sale', ascending=False)

        if not prev_valid_rows.empty:
            group.at[idx, 'est_demand'] = prev_valid_rows.iloc[0]['qty_sold']

    return group

full_df = full_df.groupby('item_id', group_keys=False).apply(adjust_demand)

# ---- Case 2: If stock < qty_sold & SUR >= 100%, use previous month's sales ----
full_df['est_demand'] = np.where(
    (full_df['available_stock'] < full_df['qty_sold']) & (full_df['Monthwise_SUR'] >= 100),
    full_df['prev_qty_sold'] + full_df['rolling_QTY_3M'],
    full_df['est_demand']
)

# ---- Case 3: If stock = 0, assume demand based on previous month's qty_sold ----
full_df['est_demand'] = np.where(
    (full_df['available_stock'] == 0),
    full_df['prev_qty_sold'],
    full_df['est_demand']
)

# ---- Case 4: Use 3-month rolling average if stockout persists ----
full_df['est_demand'] = np.where(
    (full_df['available_stock'] == 0) & (full_df['prev_available_stock'] == 0),
    full_df['rolling_QTY_3M'],
    full_df['est_demand']
)

# ---- Case 5: Use 6-month rolling average if stockout persists beyond 3 months ----
full_df['est_demand'] = np.where(
    (full_df['available_stock'] == 0) &
    (full_df['prev_available_stock'] == 0) &
    (full_df['rolling_QTY_3M'].isnull()),
    full_df['rolling_QTY_6M'],
    full_df['est_demand']
)

# ---- Case 6: Use 12-month rolling average if stockout persists beyond 6 months ----
full_df['est_demand'] = np.where(
    (full_df['available_stock'] == 0) &
    (full_df['prev_available_stock'] == 0) &
    (full_df['rolling_QTY_3M'].isnull()) &
    (full_df['rolling_QTY_6M'].isnull()),
    full_df['rolling_QTY_12M'],
    full_df['est_demand']
)

# Ensure all demand estimates are non-negative
full_df['est_demand'] = np.maximum(full_df['est_demand'], 0)

# %%
def add_lag_features(df, target_column='est_demand'):
    """
    Adds lag features for each product separately.
    """
    df = df.sort_values(by=['item_id', 'date_of_sale'])  # Ensure time order per product
    num_months = df['date_of_sale'].nunique()

    for lag in range(1, num_months):
        df[f'lag_{lag}'] = df.groupby('item_id')[target_column].shift(lag)

    df.fillna(0, inplace=True)
    return df
def add_rolling_and_change_features(df, target_column='est_demand'):
    """
    Adds rolling averages, month-over-month (MoM), and year-over-year (YoY) change features per product.
    """
    df = df.sort_values(by=['item_id', 'date_of_sale'])

    # Apply rolling calculations per product
    df['rolling_QTY_3M'] = df.groupby('item_id')[target_column].rolling(window=3, min_periods=1).mean().reset_index(level=0, drop=True)
    df['rolling_QTY_6M'] = df.groupby('item_id')[target_column].rolling(window=6, min_periods=1).mean().reset_index(level=0, drop=True)
    df['rolling_QTY_12M'] = df.groupby('item_id')[target_column].rolling(window=12, min_periods=1).mean().reset_index(level=0, drop=True)

    df['MoM_Change_Absolute'] = df.groupby('item_id')[target_column].diff(1)
    df['YoY_Change_Absolute'] = df.groupby('item_id')[target_column].diff(12)

    df.fillna(0, inplace=True)
    return df

full_df = add_lag_features(full_df)
full_df = add_rolling_and_change_features(full_df)

# %%
# !pip install tslearn
# Out:
# Collecting tslearn
#   Downloading tslearn-0.6.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tslearn) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from tslearn) (1.14.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from tslearn) (1.6.1)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from tslearn) (0.60.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from tslearn) (1.4.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->tslearn) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->tslearn) (3.6.0)
# Downloading tslearn-0.6.3-py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: tslearn
# Successfully installed tslearn-0.6.3

# %%
from sklearn.preprocessing import StandardScaler
from tslearn.clustering import TimeSeriesKMeans


time_series_rev_df = full_df.groupby(['item_id', 'date_of_sale'])['amount'].sum().reset_index()
pivot_rev_df = time_series_rev_df.pivot(index='item_id', columns='date_of_sale', values='amount').fillna(0)


scaler = StandardScaler()
normalized_rev_data = scaler.fit_transform(pivot_rev_df)
time_series_rev_data = normalized_rev_data.reshape(normalized_rev_data.shape[0], normalized_rev_data.shape[1], 1)


num_abc_clusters = 3  # A, B, C classification
dtw_kmeans_abc = TimeSeriesKMeans(n_clusters=num_abc_clusters, metric="dtw", random_state=42, init='random')
pivot_rev_df['ABC_Cluster_DTW'] = dtw_kmeans_abc.fit_predict(time_series_rev_data)
pivot_rev_df['ABC_Category_DTW'] = pivot_rev_df['ABC_Cluster_DTW'].map({0: 'A', 1: 'B', 2: 'C'})
abc_classification_dtw = pivot_rev_df[['ABC_Category_DTW']].reset_index()

# Convert DATE to datetime format
#full_df['year-month'] = pd.to_datetime(full_df['year-month'])

# Aggregate demand per item over time (daily/weekly demand)
time_series_df = full_df.groupby(['item_id', 'date_of_sale'])['est_demand'].sum().reset_index()

# Pivot to create a time-series format (rows = items, columns = dates)
pivot_df = time_series_df.pivot(index='item_id', columns='date_of_sale', values='est_demand').fillna(0)


# Normalize data (each row represents an item)
scaler = StandardScaler()
normalized_data = scaler.fit_transform(pivot_df)




# Convert data to the correct shape for DTW
time_series_data = normalized_data.reshape(normalized_data.shape[0], normalized_data.shape[1], 1)
num_clusters = 3
# Apply DTW-based K-Means
dtw_kmeans = TimeSeriesKMeans(n_clusters=num_clusters, metric="dtw", random_state=42,init='random')
pivot_df['XYZ_Cluster_DTW'] = dtw_kmeans.fit_predict(time_series_data)

# Map clusters to X, Y, Z
pivot_df['XYZ_Category_DTW'] = pivot_df['XYZ_Cluster_DTW'].map({0: 'X', 1: 'Y',2:'Z'})

# Merge back
xyz_classification_dtw = pivot_df[['XYZ_Category_DTW']].reset_index()

# Step 4: Merge ABC and XYZ classifications
abc_xyz = pd.merge(abc_classification_dtw[['item_id', 'ABC_Category_DTW']], xyz_classification_dtw[['item_id', 'XYZ_Category_DTW']], on='item_id')
# Step 5: Create ABC-XYZ matrix
abc_xyz['ABC_XYZ'] = abc_xyz['ABC_Category_DTW'] + abc_xyz['XYZ_Category_DTW']

# Display the final classification
pd.DataFrame(abc_xyz)
#print(abc_xyz.head())

# Merge ABC-XYZ classification back into the main dataset
full_df = full_df.merge(abc_xyz[['item_id', 'ABC_XYZ']], on='item_id', how='left')
print(pivot_rev_df['ABC_Category_DTW'].value_counts())
print(pivot_df['XYZ_Category_DTW'].value_counts())
print(abc_xyz['ABC_XYZ'].value_counts())
# Out:
# ABC_Category_DTW
# B    286
# A    222
# C    172
# Name: count, dtype: int64
# XYZ_Category_DTW
# X    331
# Y    188
# Z    161
# Name: count, dtype: int64
# ABC_XYZ
# BX    191
# AX    115
# CY     89
# AZ     62
# CZ     58
# BY     54
# AY     45
# BZ     41
# CX     25
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoders = {}
reverse_mappings = {}

for col in full_df.columns:
    if full_df[col].dtype == 'object' or full_df[col].apply(lambda x: isinstance(x, str)).any():
        full_df[col] = full_df[col].astype(str)  # Convert entire column to string

        if col == 'ABC_XYZ':  # Apply custom mapping
            abc_xyz_mapping = {
                'AX': 1, 'AY': 2, 'AZ': 3,
                'BX': 4, 'BY': 5, 'BZ': 6,
                'CX': 7, 'CY': 8, 'CZ': 9
            }
            reverse_mapping = {v: k for k, v in abc_xyz_mapping.items()}  # Reverse for decoding
            full_df[col] = full_df[col].map(abc_xyz_mapping)
            reverse_mappings[col] = reverse_mapping

        else:  # Apply Label Encoding for other categorical columns
            encoder = LabelEncoder()
            full_df[col] = encoder.fit_transform(full_df[col]) + 1  # Shift encoding by +1
            encoders[col] = encoder
            reverse_mappings[col] = {idx + 1: label for idx, label in enumerate(encoder.classes_)}  # Reverse mapping

print("\nReverse Mappings:")
for col, mapping in reverse_mappings.items():
    print(f"{col}: {mapping}")
# Out:
# Reverse Mappings:
# region: {1: 'California'}
# location: {1: 'California - Loc 1'}
# item_id: {1: 'Prod_1', 2: 'Prod_10', 3: 'Prod_100', 4: 'Prod_101', 5: 'Prod_102', 6: 'Prod_103', 7: 'Prod_104', 8: 'Prod_105', 9: 'Prod_106', 10: 'Prod_107', 11: 'Prod_108', 12: 'Prod_109', 13: 'Prod_11', 14: 'Prod_110', 15: 'Prod_111', 16: 'Prod_112', 17: 'Prod_113', 18: 'Prod_114', 19: 'Prod_115', 20: 'Prod_116', 21: 'Prod_117', 22: 'Prod_118', 23: 'Prod_119', 24: 'Prod_12', 25: 'Prod_120', 26: 'Prod_121', 27: 'Prod_122', 28: 'Prod_123', 29: 'Prod_124', 30: 'Prod_125', 31: 'Prod_126', 32: 'Prod_127', 33: 'Prod_128', 34: 'Prod_129', 35: 'Prod_13', 36: 'Prod_130', 37: 'Prod_131', 38: 'Prod_132', 39: 'Prod_133', 40: 'Prod_134', 41: 'Prod_135', 42: 'Prod_136', 43: 'Prod_137', 44: 'Prod_138', 45: 'Prod_139', 46: 'Prod_14', 47: 'Prod_140', 48: 'Prod_141', 49: 'Prod_142', 50: 'Prod_143', 51: 'Prod_144', 52: 'Prod_145', 53: 'Prod_146', 54: 'Prod_147', 55: 'Prod_148', 56: 'Prod_149', 57: 'Prod_15', 58: 'Prod_150', 59: 'Prod_151', 60: 'Prod_152', 61: 'Prod_153', 62: 'Prod_154', 63: 'Prod_155', 64: 'Prod_156', 65: 'Prod_157', 66: 'Prod_158', 67: 'Prod_159', 68: 'Prod_16', 69: 'Prod_160', 70: 'Prod_161', 71: 'Prod_162', 72: 'Prod_163', 73: 'Prod_164', 74: 'Prod_165', 75: 'Prod_166', 76: 'Prod_167', 77: 'Prod_168', 78: 'Prod_169', 79: 'Prod_17', 80: 'Prod_170', 81: 'Prod_171', 82: 'Prod_172', 83: 'Prod_173', 84: 'Prod_174', 85: 'Prod_175', 86: 'Prod_176', 87: 'Prod_177', 88: 'Prod_178', 89: 'Prod_179', 90: 'Prod_18', 91: 'Prod_180', 92: 'Prod_181', 93: 'Prod_182', 94: 'Prod_183', 95: 'Prod_184', 96: 'Prod_185', 97: 'Prod_186', 98: 'Prod_187', 99: 'Prod_188', 100: 'Prod_189', 101: 'Prod_19', 102: 'Prod_190', 103: 'Prod_191', 104: 'Prod_192', 105: 'Prod_193', 106: 'Prod_194', 107: 'Prod_195', 108: 'Prod_196', 109: 'Prod_197', 110: 'Prod_198', 111: 'Prod_199', 112: 'Prod_2', 113: 'Prod_20', 114: 'Prod_200', 115: 'Prod_201', 116: 'Prod_202', 117: 'Prod_203', 118: 'Prod_204', 119: 'Prod_205', 120: 'Prod_206', 121: 'Prod_207', 122: 'Prod_208', 123: 'Prod_209', 124: 'Prod_21', 125: 'Prod_210', 126: 'Prod_211', 127: 'Prod_212', 128: 'Prod_213', 129: 'Prod_214', 130: 'Prod_215', 131: 'Prod_216', 132: 'Prod_217', 133: 'Prod_218', 134: 'Prod_219', 135: 'Prod_22', 136: 'Prod_220', 137: 'Prod_221', 138: 'Prod_222', 139: 'Prod_223', 140: 'Prod_224', 141: 'Prod_225', 142: 'Prod_226', 143: 'Prod_227', 144: 'Prod_228', 145: 'Prod_229', 146: 'Prod_23', 147: 'Prod_230', 148: 'Prod_231', 149: 'Prod_232', 150: 'Prod_233', 151: 'Prod_234', 152: 'Prod_235', 153: 'Prod_236', 154: 'Prod_237', 155: 'Prod_238', 156: 'Prod_239', 157: 'Prod_24', 158: 'Prod_240', 159: 'Prod_241', 160: 'Prod_242', 161: 'Prod_243', 162: 'Prod_244', 163: 'Prod_245', 164: 'Prod_246', 165: 'Prod_247', 166: 'Prod_248', 167: 'Prod_249', 168: 'Prod_25', 169: 'Prod_250', 170: 'Prod_251', 171: 'Prod_252', 172: 'Prod_253', 173: 'Prod_254', 174: 'Prod_255', 175: 'Prod_256', 176: 'Prod_257', 177: 'Prod_258', 178: 'Prod_259', 179: 'Prod_26', 180: 'Prod_260', 181: 'Prod_261', 182: 'Prod_262', 183: 'Prod_263', 184: 'Prod_264', 185: 'Prod_265', 186: 'Prod_266', 187: 'Prod_267', 188: 'Prod_268', 189: 'Prod_269', 190: 'Prod_27', 191: 'Prod_270', 192: 'Prod_271', 193: 'Prod_272', 194: 'Prod_273', 195: 'Prod_274', 196: 'Prod_275', 197: 'Prod_276', 198: 'Prod_277', 199: 'Prod_278', 200: 'Prod_279', 201: 'Prod_28', 202: 'Prod_280', 203: 'Prod_281', 204: 'Prod_282', 205: 'Prod_283', 206: 'Prod_284', 207: 'Prod_285', 208: 'Prod_286', 209: 'Prod_287', 210: 'Prod_288', 211: 'Prod_289', 212: 'Prod_29', 213: 'Prod_290', 214: 'Prod_291', 215: 'Prod_292', 216: 'Prod_293', 217: 'Prod_294', 218: 'Prod_295', 219: 'Prod_296', 220: 'Prod_297', 221: 'Prod_298', 222: 'Prod_299', 223: 'Prod_3', 224: 'Prod_30', 225: 'Prod_300', 226: 'Prod_301', 227: 'Prod_302', 228: 'Prod_303', 229: 'Prod_304', 230: 'Prod_305', 231: 'Prod_306', 232: 'Prod_307', 233: 'Prod_308', 234: 'Prod_309', 235: 'Prod_31', 236: 'Prod_310', 237: 'Prod_311', 238: 'Prod_312', 239: 'Prod_313', 240: 'Prod_314', 241: 'Prod_315', 242: 'Prod_316', 243: 'Prod_3 ...
# ABC_XYZ: {1: 'AX', 2: 'AY', 3: 'AZ', 4: 'BX', 5: 'BY', 6: 'BZ', 7: 'CX', 8: 'CY', 9: 'CZ'}

# %%
full_df.replace([np.inf, -np.inf], 0, inplace=True)
df_monthly_train = full_df[full_df['date_of_sale'] < '2024-09-01']
df_monthly_test = full_df[full_df['date_of_sale'] >= '2024-09-01']
df_monthly_train_inverse = df_monthly_train.copy()
df_monthly_train_inverse['item_id'] =  df_monthly_train['item_id'].map(reverse_mappings['item_id'])
df_monthly_train_inverse['location'] =  df_monthly_train['location'].map(reverse_mappings['location'])
df_monthly_train_inverse['region'] =  df_monthly_train['item_id'].map(reverse_mappings['region'])
shop_name = df_monthly_train_inverse['location'].iloc[0]  # Take first row
region_name = df_monthly_train_inverse['region'].iloc[0]

# %%
lost_revenue = ((df_monthly_train['rate']* df_monthly_train['est_demand']) - df_monthly_train['amount']).sum()
lost_revenue

# %%
lost_demand = (df_monthly_train['est_demand']) - df_monthly_train['qty_sold']
lost_demand = lost_demand[lost_demand > 0].sum()
lost_demand

# %%
exclude_cols = [ 'amount', 'date_of_sale','item_id','est_demand','stock_reduction',#'Quarterly_SUR','Monthwise_SUR','Avg_Utilisation',
                'available_stock','stockout_flag','quarter',
                'prev_available_stock','prev_qty_sold','stock_reduction','Quarterly_SUR']
exogenous_features = [col for col in df_monthly_train.select_dtypes(include=['number']).columns if col not in exclude_cols]

# %%
import xgboost as xgb
#from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
import tensorflow as tf
import lightgbm as lgb
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
import shap
#from prophet import Prophet

from statsmodels.tsa.stattools import adfuller, kpss
warnings.filterwarnings("ignore")
'''
exogenous_features = ['rate', 'holidays', 'discount',
       'loyalty_discount', 'promotions', 'lag_1', 'lag_2', 'lag_3', 'lag_4',
       'lag_5', 'lag_6', 'lag_7', 'lag_8', 'lag_9', 'lag_10', 'lag_11',
       'lag_12', 'lag_13', 'lag_14', 'lag_15', 'lag_16', 'lag_17', 'lag_18',
       'lag_19', 'lag_20', 'lag_21', 'lag_22', 'lag_23', 'lag_24', 'rolling_QTY_3M',
       'rolling_QTY_6M', 'rolling_QTY_12M', 'MoM_Change_Absolute',
       'YoY_Change_Absolute',  'ABC_XYZ']
'''

print("Exogenous Features:", exogenous_features)

abc_xyz_mapping = {
    1: 'AX',
    2: 'AY',
    3: 'AZ',
    4: 'BX',
    5: 'BY',
    6: 'BZ',
    7: 'CX',
    8: 'CY',
    9: 'CZ'
}


def is_stationary(timeseries):
    """Check if a time series is stationary using ADF and KPSS tests."""
    if timeseries.nunique() == 1:
        return False
    adf_pvalue = adfuller(timeseries)[1]
    try:
        kpss_pvalue = kpss(timeseries, nlags="auto")[1]
    except ValueError:
        kpss_pvalue = 0
    return adf_pvalue < 0.05 and kpss_pvalue > 0.05

def train_lstm(train_x, train_y):
    model = Sequential()
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(train_x.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(train_x.shape[1], 1)))
    model.add(Dropout(0.2))
    model.add(LSTM(50, activation='relu'))
    model.add(Dense(1))
    model.compile(optimizer='adam', loss='mse',metrics='mae')
    model.fit(train_x, train_y, epochs=50, batch_size=16, verbose=0)
    return model

# Function to select top features based on percentage
def select_top_features(train_x, train_y, model, top_percent=10):
    explainer = shap.Explainer(model, train_x)
    shap_values = explainer(train_x, check_additivity=False)

    feature_importance = np.abs(shap_values.values).mean(axis=0)
    feature_importance_df = pd.DataFrame({'feature': train_x.columns, 'importance': feature_importance})

    # Calculate number of features based on percentage
    num_features = max(1, int(len(train_x.columns) * (top_percent / 100)))

    # Select the top N% features
    top_features = feature_importance_df.sort_values(by='importance', ascending=False).head(num_features)['feature'].tolist()

    return top_features

def forecast_product(item_df, abc_xyz_category):
    item = item_df['item_id'].iloc[0]
    item_df = item_df[['date_of_sale', 'est_demand'] + exogenous_features].rename(columns={'date_of_sale': 'ds', 'est_demand': 'y'})
    item_df['ds'] = pd.to_datetime(item_df['ds'])
    item_df1 = item_df[['ds', 'y']]
    # Handle missing regressors
    missing_cols = [col for col in exogenous_features if col not in item_df.columns]
    for col in missing_cols:
        item_df[col] = 0  # Default fill with zero

    # Handle constant regressors
    valid_regressors = item_df[exogenous_features].nunique()[item_df[exogenous_features].nunique() > 1].index.tolist()
    train_x = item_df[valid_regressors]
    train_y = item_df['y']

    model = xgb.XGBRegressor(objective='reg:squarederror', eval_metric='mae', random_state=42)
    model.fit(train_x, train_y)

    # Select top 45 features using SHAP
    top_features = select_top_features(train_x, train_y, model, top_percent=10)


    model_type = abc_xyz_mapping.get(abc_xyz_category, 'Default Model')

    if model_type in ["AX","BX","CX"]:
        #model = RandomForestRegressor(random_state=42,criterion='squared_error',max_samples = None, max_depth = None,max_leaf_nodes = None,
          #                            max_features=0.9,bootstrap=True,warm_start=True,oob_score=True)
        #model = lgb.LGBMRegressor(objective='regression', metric='mae', random_state=42,verbose=0)
        model = xgb.XGBRegressor(objective= 'reg:squarederror',eval_metric= 'mae',random_state= 42,learning_rate = 0.1)
        train_x, train_y = item_df[top_features], item_df['y']
        model.fit(train_x, train_y)
        y_pred = model.predict(train_x.iloc[-3:])

    elif model_type in ["AY","BY","CY"]:
        #train_x, train_y = item_df[valid_regressors], item_df['y']
        #lstm_model = train_lstm(train_x, train_y)
        #train_x = np.reshape(train_x.values, (train_x.shape[0], train_x.shape[1], 1))
        #y_pred = lstm_model.predict(train_x[-3:]).flatten()
        #model = xgb.XGBRegressor(objective= 'reg:squarederror',eval_metric= 'mae',random_state= 42,learning_rate = 0.1)
        model = lgb.LGBMRegressor(objective='regression', metric='mae', random_state=42,verbose=-1)
        train_x, train_y = item_df[valid_regressors], item_df['y']
        model.fit(train_x, train_y)
        y_pred = model.predict(train_x.iloc[-3:])
    elif model_type in ["AZ","BZ","CZ"]:
        #model = xgb.XGBRegressor(objective= 'reg:squarederror',eval_metric= 'mae',random_state= 42,
         #                        max_depth = None,reg_alpha = 1,reg_lambda = 1)
        model = RandomForestRegressor(random_state=42,criterion='squared_error',max_samples = None, max_depth = 12,max_leaf_nodes = None,
                                     max_features=0.9,bootstrap=True,warm_start=True,oob_score=True,verbose = 0)
        train_x, train_y = item_df[top_features], item_df['y']
        model.fit(train_x, train_y)
        y_pred = model.predict(train_x.iloc[-3:])
    else:
        model = xgb.XGBRegressor(objective='reg:squarederror', eval_metric='mae', random_state=42)
        train_x, train_y = item_df[top_features], item_df['y']
        model.fit(train_x, train_y)
        future_regressors = item_df[valid_regressors].iloc[-3:].reset_index(drop=True)
        y_pred = model.predict(future_regressors)

    y_actual = []  # Store the final 3 values
    historical_years = 3

    for i in range(1, 4):  # Forecast for next 3 months
        past_values = []

        for year in range(1, historical_years + 1):
            past_index = -i - (year * 12)  # Get past value from 1, 2, and 3 years ago

            if abs(past_index) <= len(item_df):  # Ensure index is within bounds
                past_values.append(item_df['y'].iloc[past_index])

        # Compute moving average (or weighted avg if needed)
        if past_values:
            y_actual.append(np.mean(past_values))  # Moving average of past values
        else:
            y_actual.append(0)  # Default to 0 if no past data

    y_actual = np.array(y_actual)


    if np.any(y_actual[:-1] == 0):
        recent_growth_rate = 0
    else:

        weights = np.linspace(1, 2, len(y_actual[12:]))  # Increasing weights (recent data gets higher priority)
        weights = np.linspace(1, 2, len(y_actual[12:]))  # Increasing weights (recent data gets higher priority)

        # Ensure the weights sum to a valid value
        if np.sum(weights) == 0:
            recent_growth_rate = 0  # Default to no trend adjustment
        else:
            recent_growth_rate = np.average(
                (y_actual[12:] / np.clip(y_actual[:-12], 1e-6, None)) - 1,
                weights=weights
            )




    mae = mean_absolute_error(y_actual, y_pred)
    bias = np.mean(y_pred - y_actual)


    if np.isnan(bias) or np.isinf(bias):
        bias = 0

    if np.isnan(recent_growth_rate) or np.isinf(recent_growth_rate):
        recent_growth_rate = 0  # Default to no trend adjustment

    adjusted_forecast = (y_pred - (bias)) * (1 + (recent_growth_rate))
    adjusted_forecast = np.nan_to_num(adjusted_forecast, nan=0, posinf=np.max(y_actual), neginf=np.min(y_actual))
    #adjusted_forecast = y_pred - bias
    adjusted_forecast = np.clip(adjusted_forecast, 0, None)

    return item, y_pred, adjusted_forecast, mae, bias, model_type

results = []
for item, group in df_monthly_train.groupby('item_id'):
    abc_xyz_category = df_monthly_train.loc[df_monthly_train['item_id'] == item, 'ABC_XYZ'].values[0]
    try:
        print(f'Running Forecast for Product: {item} ({abc_xyz_category})')
        results.append(forecast_product(group, abc_xyz_category))
    except Exception as e:
        print(f'Error forecasting for Product {item}: {str(e)}')

# Get the last date from the training data
last_train_month = df_monthly_train['date_of_sale'].max()  # Assuming 'year-month' is a datetime column
last_train_month = pd.to_datetime(last_train_month)  # Ensure it's in datetime format

# Generate forecast month names
forecast_months = [(last_train_month + pd.DateOffset(months=i)).strftime('%b %Y') for i in range(1, 4)]
forecast_results = pd.DataFrame(results, columns=['Encoded_ITEMNUMBER', 'Raw Forecast', 'Adjusted Forecast', 'MAE', 'Bias',
                                                   'model_type'])

forecast_results['item_id'] = forecast_results['Encoded_ITEMNUMBER'].map(reverse_mappings['item_id'])
forecast_results[forecast_months] = forecast_results['Adjusted Forecast'].apply(
    lambda x: pd.Series(x[:3]) if isinstance(x, (list, np.ndarray)) else pd.Series([None, None, None])
)
forecast_results.drop(columns=['Adjusted Forecast', 'Raw Forecast', 'Encoded_ITEMNUMBER'], inplace=True)
forecast_results['location'] = shop_name
forecast_results['region'] = region_name
forecast_results['lost_revenue'] = lost_revenue
forecast_results.head()
# Out:
# Exogenous Features: ['shelf_life', 'region', 'location', 'rate', 'available_stock', 'holidays', 'discount', 'loyalty_discount', 'promotions', 'year', 'month', 'quarter', 'Monthwise_SUR', 'Avg_Utilisation', 'Quarterly_SUR', 'prev_available_stock', 'prev_qty_sold', 'stock_reduction', 'stockout_flag', 'rolling_QTY_3M', 'rolling_QTY_6M', 'rolling_QTY_12M', 'lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5', 'lag_6', 'lag_7', 'lag_8', 'lag_9', 'lag_10', 'lag_11', 'lag_12', 'lag_13', 'lag_14', 'lag_15', 'lag_16', 'lag_17', 'lag_18', 'lag_19', 'lag_20', 'lag_21', 'lag_22', 'lag_23', 'lag_24', 'lag_25', 'lag_26', 'lag_27', 'lag_28', 'lag_29', 'lag_30', 'lag_31', 'lag_32', 'lag_33', 'lag_34', 'lag_35', 'lag_36', 'lag_37', 'lag_38', 'lag_39', 'lag_40', 'lag_41', 'lag_42', 'lag_43', 'lag_44', 'lag_45', 'lag_46', 'lag_47', 'lag_48', 'lag_49', 'lag_50', 'lag_51', 'lag_52', 'lag_53', 'lag_54', 'lag_55', 'lag_56', 'lag_57', 'lag_58', 'lag_59', 'lag_60', 'lag_61', 'lag_62', 'lag_63', 'lag_64', 'lag_65', 'lag_66', 'lag_67', 'lag_68', 'lag_69', 'lag_70', 'lag_71', 'MoM_Change_Absolute', 'YoY_Change_Absolute', 'ABC_XYZ']
# Running Forecast for Product: 1 (6)
# Running Forecast for Product: 2 (4)
# Running Forecast for Product: 3 (1)
# Running Forecast for Product: 4 (4)
# Running Forecast for Product: 5 (5)
# Running Forecast for Product: 6 (1)
# Running Forecast for Product: 7 (9)
# Running Forecast for Product: 8 (5)
# Running Forecast for Product: 9 (8)
# Running Forecast for Product: 10 (7)
# Running Forecast for Product: 11 (4)
# Running Forecast for Product: 12 (2)
# Running Forecast for Product: 13 (4)
# Running Forecast for Product: 14 (4)
# Running Forecast for Product: 15 (1)
# Running Forecast for Product: 16 (8)
# Running Forecast for Product: 17 (9)
# Running Forecast for Product: 18 (8)
# Running Forecast for Product: 19 (4)
# Running Forecast for Product: 20 (1)
# Running Forecast for Product: 21 (4)
# Running Forecast for Product: 22 (4)
# Running Forecast for Product: 23 (9)
# Running Forecast for Product: 24 (2)
# Running Forecast for Product: 25 (7)
# Running Forecast for Product: 26 (6)
# Running Forecast for Product: 27 (9)
# Running Forecast for Product: 28 (8)
# Running Forecast for Product: 29 (1)
# Running Forecast for Product: 30 (8)
# Running Forecast for Product: 31 (5)
# Running Forecast for Product: 32 (4)
# Running Forecast for Product: 33 (1)
# Running Forecast for Product: 34 (1)
# Running Forecast for Product: 35 (6)
# Running Forecast for Product: 36 (4)
# Running Forecast for Product: 37 (7)
# Running Forecast for Product: 38 (8)
# Running Forecast for Product: 39 (4)
# Running Forecast for Product: 40 (3)
# Running Forecast for Product: 41 (5)
# Running Forecast for Product: 42 (2)
# Running Forecast for Product: 43 (1)
# Running Forecast for Product: 44 (4)
# Running Forecast for Product: 45 (3)
# Running Forecast for Product: 46 (1)
# Running Forecast for Product: 47 (4)
# Running Forecast for Product: 48 (8)
# Running Forecast for Product: 49 (5)
# Running Forecast for Product: 50 (4)
# Running Forecast for Product: 51 (1)
# Running Forecast for Product: 52 (1)
# Running Forecast for Product: 53 (9)
# Running Forecast for Product: 54 (4)
# Running Forecast for Product: 55 (4)
# Running Forecast for Product: 56 (6)
# Running Forecast for Product: 57 (6)
# Running Forecast for Product: 58 (1)
# Running Forecast for Product: 59 (4)
# Running Forecast for Product: 60 (8)
# Running Forecast for Product: 61 (3)
# Running Forecast for Product: 62 (9)
# Running Forecast for Product: 63 (1)
# Running Forecast for Product: 64 (5)
# Running Forecast for Product: 65 (8)
# Running Forecast for Product: 66 (8)
# Running Forecast for Product: 67 (6)
# Running Forecast for Product: 68 (1)
# Running Forecast for Product: 69 (9)
# Running Forecast for Product: 70 (3)
# Running Forecast for Product: 71 (4)
# Running Forecast for Product: 72 (9)
# Running Forecast for Product: 73 (6)
# Running Forecast for Product: 74 (6)
# Running Forecast for Product: 75 (8)
# Running Forecast for Product: 76 (4)
# Running Forecast for Product: 77 (3)
# Running Forecast for Product: 78 (6)
# Running Forecast for Product: 79 (1)
# Running Forecast for Product: 80 (3)
# Running Forecast for Product: 81 (5)
# Running Forecast for Product: 82 (1)
# Running Forecast for Product: 83 (6)
# Running Forecast for Product: 84 (4)
# Running Forecast for Product: 85 (2)
# Running Forecast for Product: 86 (8)
# Running Forecast for Product: 87 (8)
# Running Forecast for Product: 88 (4)
# Running Forecast for Product: 89 (3)
# Running Forecast for Product: 90 (2)
# Running Forecast for Product: 91 (3)
# Running Forecast for Product: 92 (4)
# Running Forecast for Product: 93 (3)
# Running Forecast for Product: 94 (9)
# Running Forecast for Product: 95 (2)
# Running Forecast for Product: 96 (5)
# Running Forecast for Product: 97 (9)
# Running Forecast for Product: 98 (1)
# Running Forecast for Product: 99 (4)
# Running Forecast for Product: 100 (1)
# Running Forecast for Product: 101 (3)
# Running Forecast for Product: 102 (2)
# Running Forecast for Product: 103 (1)
# Running Forecast for Product: 104 (5)
# Running Forecast for Product: 105 (8)
# Running Forecast for Product: 106 (3)
# Running Forecast for Product: 107 (4)
# Running Forecast for Product: 108 (2)
# Running Forecast for Product: 109 (9)
# Running Forecast for Product: 110 (1)
# Running Forecast for Product: 111 (3)
# Running Forecast for Product: 112 (4)
# Running Forecast for Product: 113 (7)
# Running Forecast for Product: 114 (4)
# Running Forecast for Product: 115 (4)
# Running Forecast for Product: 116 (2)
# Running Forecast for Product: 117 (4)
# Running Forecast for Product: 118 (4)
# Running Forecast for Product: 119 (4)
# Running Forecast for Product: 120 (1)
# Running Forecast for Product: 121 (5)
# Running Forecast for Product: 122 (1)
# Running Forecast for Product: 123 (8)
# Running Forecast for Product: 124 (8)
# Running Forecast for Product: 125 (9)
# Running Forecast for Product: 126 (9)
# Running Forecast for Product: 127 (8)
# Running Forecast for Product: 128 (2)
# Running Forecast for Product: 129 (8)
# Running Forecast for Product: 130 (8)
# Running Forecast for Product: 131 (4)
# Running Forecast for Product: 132 (1)
# Running Forecast for Product: 133 (5)
# Running Forecast for Product: 134 (4)
# Running Forecast for Product: 135 (5)
# Running Forecast for Product: 136 (8)
# Running Forecast for Product: 137 (8)
# Running Forecast for Product: 138 (1)
# Running Forecast for Product: 139 (1)
# Running Forecast for Product: 140 (1)
# Running Forecast for Product: 141 (9)
# Running Forecast for Product: 142 (4)
# Running Forecast for Product: 143 (3)
# Running Forecast for Product: 144 (4)
# Running Forecast for Product: 145 (1)
# Running Forecast for Product: 146 (1)
# Running Forecast for Product: 147 (5)
# Running Forecast for Product: 148 (1)
# Running Forecast for Product: 149 (2)
# Running Forecast for Product: 150 (7)
# Running Forecast for Product: 151 (4)
# Running Forecast for Product: 152 (8)
# Running Forecast for Product: 153 (5)
# Running Forecast for Product: 154 (1)
# Running Forecast for Product: 155 (3)
# Running Forecast for Product: 156 (4)
# Running Forecast for Product: 157 (5)
# Running Forecast for Product: 158 (8)
# Running Forecast for Product: 159 (8)
# Running Forecast for Product: 160 (1)
# Running Forecast for Product: 161 (7)
# Running Forecast for Product: 162 (2)
# Running Forecast for Product: 163 (9)
# Running Forecast for Product: 164 (1)
# Running Forecast for Product: 165 (4)
# Running Forecast for Product: 166 (1)
# Running Forecast for Product: 167 (5)
# Running Forecast for Product: 168 (4)
# Running Forecast for Product: 169 (8)
# Running Forecast for Product: 170 (4)
# Running Forecast for Product: 171 (6)
# Running Forecast for Product: 172 (5)
# Running Forecast for Product: 173 (9)
# Running Forecast for Product: 174 (1)
# Running Forecast for Product: 175 (4)
# Running Forecast for Product: 176 (6)
# Running Forecast for Product: 177 (7)
# Running Forecast for Product: 178 (3)
# Running Forecast for Product: 179 (8)
# Running Forecast for Product: 180 (2)
# Running Forecast for Product: 181 (4)
# Running Forecast for Product: 182 (4)
# Running Forecast for Product: 183 (1)
# Running Forecast for Product: 184 (1)
# Running Forecast for Product: 185 (4)
# Running Forecast for Product: 186 (4)
# Running Forecast for Product: 187 (8)
# Running Forecast for Product: 188 (1)
# Running Forecast for Product: 189 (4)
# Running Forecast for Product: 190 (4)
# Running Forecast for Product: 191 (8)
# Running Forecast for Product: 192 (9)
# Running Forecast for Product: 193 (3)
# Running Forecast for Product: 194 (3)
# Running Forecast for Product: 195 (1)
# Running Forecast for Product: 196 (2)
# Running Forecast for Product: 197 (4)
# Running Forecast for Product: 198 (1)
# Running Forecast for Product: 199 (8)
# Running Forecast for Product: 200 (4)
# Running Forecast for Product: 201 (6)
# Running Forecast for Product: 202 (5)
# Running Forecast for Product: 203 (1)
# Running Forecast for Product: 204 (8)
# Running Forecast for Product: 205 (9)
# Running Forecast for Product: 206 (1)
# Running Forecast for Product: 207 (8)
# Running Forecast for Product: 208 (1)
# Running Forecast for Product: 209 (3)
# Running Forecast for Product: 210 (4)
# Running Forecast for Product: 211 (5)
# Running Forecast for Product: 212 (5)
# Running Forecast for Product: 213 (4)
# Running Forecast for Product: 214 (1)
# Running Forecast for Product: 215 (3)
# Running Forecast for Product: 216 (5)
# Running Forecast for Product: 217 (4)
# Running Forecast for Product: 218 (3)
# Running Forecast for Product: 219 (4)
# Running Forecast for Product: 220 (4)
# Running Forecast for Product: 221 (8)
# Running Forecast for Product: 222 (2)
# Running Forecast for Product: 223 (3)
# Running Forecast for Product: 224 (4)
# Running Forecast for Product: 225 (2)
# Running Forecast for Product: 226 (4)
# Running Forecast for Product: 227 (8)
# Running Forecast for Product: 228 (1)
# Running Forecast for Product: 229 (4)
# Running Forecast for Product: 230 (8)
# Running Forecast for Product: 231 (1)
# Running Forecast for Product: 232 (5)
# Running Forecast for Product: 233 (4)
# Running Forecast for Product: 234 (5)
# Running Forecast for Product: 235 (4)
# Running Forecast for Product: 236 (1)
# Running Forecast for Product: 237 (6)
# Running Forecast for Product: 238 (4)
# Running Forecast for Product: 239 (5)
# Running Forecast for Product: 240 (4)
# Running Forecast for Product: 241 (4)
# Running Forecast for Product: 242 (4)
# Running Forecast for Product: 243 (8)
# Running Forecast for Product: 244 (4)
# Running Forecast for Product: 245 (4)
# Running Forecast for Product: 246 (8)
# Running Forecast for Product: 247 (9)
# Running Forecast for Product: 248 (7)
# Running Forecast for Product: 249 (2)
# Running Forecast for Product: 250 (1)
# Running Forecast for Product: 251 (6)
# Running Forecast for Product: 252 (1)
# Running Forecast for Product: 253 (3)
# Running Forecast for Product: 254 (5)
# Running Forecast for Product: 255 (4)
# Running Forecast for Product: 256 (2)
# Running Forecast for Product: 257 (9)
# Running Forecast for Product: 258 (4)
# Running Forecast for Product: 259 (1)
# Running Forecast for Product: 260 (2)
# Running Forecast for Product: 261 (4)
# Running Forecast for Product: 262 (3)
# Running Forecast for Product: 263 (8)
# Running Forecast for Product: 264 (2)
# Running Forecast for Product: 265 (6)
# Running Forecast for Product: 266 (8)
# Running Forecast for Product: 267 (9)
# Running Forecast for Product: 268 (4)
# Running Forecast for Product: 269 (1)
# Running Forecast for Product: 270 (1)
# Running Forecast for Product: 271 (9)
# Running Forecast for Product: 272 (4)
# Running Forecast for Product: 273 (3)
# Running Forecast for Product: 274 (8)
# Running Forecast for Product: 275 (4)
# Running Forecast for Product: 276 (3)
# Running Forecast for Product: 277 (1)
# Running Forecast for Product: 278 (7)
# Running Forecast for Product: 279 (4)
# Running Forecast for Product: 280 (1)
# Running Forecast for Product: 281 (5)
# Running Forecast for Product: 282 (9)
# Running Forecast for Product: 283 (8)
# Running Forecast for Product: 284 (2)
# Running Forecast for Product: 285 (4)
# Running Forecast for Product: 286 (1)
# Running Forecast for Product: 287 (8)
# Running Forecast for Product: 288 (5)
# Running Forecast for Product: 289 (4)
# Running Forecast for Product: 290 (1)
# Running Forecast for Product: 291 (1)
# Running Forecast for Product: 292 (8)
# Running Forecast for Product: 293 (9)
# Running Forecast for Product: 294 (9)
# Running Forecast for Product: 295 (4)
# Running Forecast for Product: 296 (8)
# Running Forecast for Product: 297 (4)
# Running Forecast for Product: 298 (1)
# Running Forecast for Product: 299 (5)
# Running Forecast for Product: 300 (7)
# Running Forecast for Product: 301 (1)
# Running Forecast for Product: 302 (4)
# Running Forecast for Product: 303 (9)
# Running Forecast for Product: 304 (6)
# Running Forecast for Product: 305 (8)
# Running Forecast for Product: 306 (1)
# Running Forecast for Product: 307 (8)
# Running Forecast for Product: 308 (1)
# Running Forecast for Product: 309 (1)
# Running Forecast for Product: 310 (8)
# Running Forecast for Product: 311 (5)
# Running Forecast for Product: 312 (4)
# Running Forecast for Product: 313 (1)
# Running Forecast for Product: 314 (1)
# Running Forecast for Product: 315 (1)
# Running Forecast for Product: 316 (4)
# Running Forecast for Product: 317 (3)
# Running Forecast for Product: 318 (1)
# Running Forecast for Product: 319 (1)
# Running Forecast for Product: 320 (8)
# Running Forecast for Product: 321 (4)
# Running Forecast for Product: 322 (7)
# Running Forecast for Product: 323 (4)
# Running Forecast for Product: 324 (4)
# Running Forecast for Product: 325 (3)
# Running Forecast for Product: 326 (1)
# Running Forecast for Product: 327 (5)
# Running Forecast for Product: 328 (5)
# Running Forecast for Product: 329 (9)
# Running Forecast for Product: 330 (2)
# Running Forecast for Product: 331 (8)
# Running Forecast for Product: 332 (6)
# Running Forecast for Product: 333 (5)
# Running Forecast for Product: 334 (6)
# Running Forecast for Product: 335 (5)
# Running Forecast for Product: 336 (4)
# Running Forecast for Product: 337 (2)
# Running Forecast for Product: 338 (6)
# Running Forecast for Product: 339 (1)
# Running Forecast for Product: 340 (8)
# Running Forecast for Product: 341 (9)
# Running Forecast for Product: 342 (4)
# Running Forecast for Product: 343 (5)
# Running Forecast for Product: 344 (9)
# Running Forecast for Product: 345 (4)
# Running Forecast for Product: 346 (4)
# Running Forecast for Product: 347 (6)
# Running Forecast for Product: 348 (7)
# Running Forecast for Product: 349 (7)
# Running Forecast for Product: 350 (6)
# Running Forecast for Product: 351 (8)
# Running Forecast for Product: 352 (3)
# Running Forecast for Product: 353 (8)
# Running Forecast for Product: 354 (5)
# Running Forecast for Product: 355 (4)
# Running Forecast for Product: 356 (3)
# Running Forecast for Product: 357 (2)
# Running Forecast for Product: 358 (6)
# Running Forecast for Product: 359 (8)
# Running Forecast for Product: 360 (2)
# Running Forecast for Product: 361 (4)
# Running Forecast for Product: 362 (9)
# Running Forecast for Product: 363 (6)
# Running Forecast for Product: 364 (1)
# Running Forecast for Product: 365 (4)
# Running Forecast for Product: 366 (1)
# Running Forecast for Product: 367 (9)
# Running Forecast for Product: 368 (2)
# Running Forecast for Product: 369 (8)
# Running Forecast for Product: 370 (4)
# Running Forecast for Product: 371 (1)
# Running Forecast for Product: 372 (3)
# Running Forecast for Product: 373 (4)
# Running Forecast for Product: 374 (5)
# Running Forecast for Product: 375 (4)
# Running Forecast for Product: 376 (4)
# Running Forecast for Product: 377 (2)
# Running Forecast for Product: 378 (4)
# Running Forecast for Product: 379 (4)
# Running Forecast for Product: 380 (7)
# Running Forecast for Product: 381 (4)
# Running Forecast for Product: 382 (6)
# Running Forecast for Product: 383 (1)
# Running Forecast for Product: 384 (3)
# Running Forecast for Product: 385 (1)
# Running Forecast for Product: 386 (8)
# Running Forecast for Product: 387 (4)
# Running Forecast for Product: 388 (4)
# Running Forecast for Product: 389 (4)
# Running Forecast for Product: 390 (5)
# Running Forecast for Product: 391 (1)
# Running Forecast for Product: 392 (8)
# Running Forecast for Product: 393 (9)
# Running Forecast for Product: 394 (4)
# Running Forecast for Product: 395 (3)
# Running Forecast for Product: 396 (4)
# Running Forecast for Product: 397 (3)
# Running Forecast for Product: 398 (8)
# Running Forecast for Product: 399 (2)
# Running Forecast for Product: 400 (3)
# Running Forecast for Product: 401 (4)
# Running Forecast for Product: 402 (5)
# Running Forecast for Product: 403 (8)
# Running Forecast for Product: 404 (4)
# Running Forecast for Product: 405 (3)
# Running Forecast for Product: 406 (8)
# Running Forecast for Product: 407 (4)
# Running Forecast for Product: 408 (4)
# Running Forecast for Product: 409 (7)
# Running Forecast for Product: 410 (4)
# Running Forecast for Product: 411 (1)
# Running Forecast for Product: 412 (1)
# Running Forecast for Product: 413 (4)
# Running Forecast for Product: 414 (3)
# Running Forecast for Product: 415 (1)
# Running Forecast for Product: 416 (4)
# Running Forecast for Product: 417 (2)
# Running Forecast for Product: 418 (3)
# Running Forecast for Product: 419 (7)
# Running Forecast for Product: 420 (4)
# Running Forecast for Product: 421 (4)
# Running Forecast for Product: 422 (5)
# Running Forecast for Product: 423 (4)
# Running Forecast for Product: 424 (4)
# Running Forecast for Product: 425 (4)
# Running Forecast for Product: 426 (9)
# Running Forecast for Product: 427 (4)
# Running Forecast for Product: 428 (6)
# Running Forecast for Product: 429 (4)
# Running Forecast for Product: 430 (4)
# Running Forecast for Product: 431 (8)
# Running Forecast for Product: 432 (9)
# Running Forecast for Product: 433 (9)
# Running Forecast for Product: 434 (1)
# Running Forecast for Product: 435 (4)
# Running Forecast for Product: 436 (5)
# Running Forecast for Product: 437 (9)
# Running Forecast for Product: 438 (3)
# Running Forecast for Product: 439 (1)
# Running Forecast for Product: 440 (9)
# Running Forecast for Product: 441 (5)
# Running Forecast for Product: 442 (2)
# Running Forecast for Product: 443 (4)
# Running Forecast for Product: 444 (1)
# Running Forecast for Product: 445 (7)
# Running Forecast for Product: 446 (1)
# Running Forecast for Product: 447 (1)
# Running Forecast for Product: 448 (8)
# Running Forecast for Product: 449 (8)
# Running Forecast for Product: 450 (3)
# Running Forecast for Product: 451 (1)
# Running Forecast for Product: 452 (1)
# Running Forecast for Product: 453 (4)
# Running Forecast for Product: 454 (4)
# Running Forecast for Product: 455 (1)
# Running Forecast for Product: 456 (2)
# Running Forecast for Product: 457 (4)
# Running Forecast for Product: 458 (1)
# Running Forecast for Product: 459 (1)
# Running Forecast for Product: 460 (2)
# Running Forecast for Product: 461 (3)
# Running Forecast for Product: 462 (7)
# Running Forecast for Product: 463 (1)
# Running Forecast for Product: 464 (9)
# Running Forecast for Product: 465 (4)
# Running Forecast for Product: 466 (3)
# Running Forecast for Product: 467 (1)
# Running Forecast for Product: 468 (4)
# Running Forecast for Product: 469 (3)
# Running Forecast for Product: 470 (1)
# Running Forecast for Product: 471 (4)
# Running Forecast for Product: 472 (4)
# Running Forecast for Product: 473 (8)
# Running Forecast for Product: 474 (1)
# Running Forecast for Product: 475 (1)
# Running Forecast for Product: 476 (4)
# Running Forecast for Product: 477 (4)
# Running Forecast for Product: 478 (7)
# Running Forecast for Product: 479 (4)
# Running Forecast for Product: 480 (4)
# Running Forecast for Product: 481 (4)
# Running Forecast for Product: 482 (4)
# Running Forecast for Product: 483 (8)
# Running Forecast for Product: 484 (4)
# Running Forecast for Product: 485 (6)
# Running Forecast for Product: 486 (4)
# Running Forecast for Product: 487 (8)
# Running Forecast for Product: 488 (8)
# Running Forecast for Product: 489 (8)
# Running Forecast for Product: 490 (4)
# Running Forecast for Product: 491 (8)
# Running Forecast for Product: 492 (4)
# Running Forecast for Product: 493 (6)
# Running Forecast for Product: 494 (6)
# Running Forecast for Product: 495 (9)
# Running Forecast for Product: 496 (4)
# Running Forecast for Product: 497 (2)
# Running Forecast for Product: 498 (6)
# Running Forecast for Product: 499 (6)
# Running Forecast for Product: 500 (8)
# Running Forecast for Product: 501 (5)
# Running Forecast for Product: 502 (4)
# Running Forecast for Product: 503 (1)
# Running Forecast for Product: 504 (8)
# Running Forecast for Product: 505 (2)
# Running Forecast for Product: 506 (3)
# Running Forecast for Product: 507 (7)
# Running Forecast for Product: 508 (5)
# Running Forecast for Product: 509 (7)
# Running Forecast for Product: 510 (9)
# Running Forecast for Product: 511 (7)
# Running Forecast for Product: 512 (4)
# Running Forecast for Product: 513 (6)
# Running Forecast for Product: 514 (4)
# Running Forecast for Product: 515 (6)
# Running Forecast for Product: 516 (4)
# Running Forecast for Product: 517 (9)
# Running Forecast for Product: 518 (5)
# Running Forecast for Product: 519 (3)
# Running Forecast for Product: 520 (4)
# Running Forecast for Product: 521 (3)
# Running Forecast for Product: 522 (4)
# Running Forecast for Product: 523 (4)
# Running Forecast for Product: 524 (8)
# Running Forecast for Product: 525 (1)
# Running Forecast for Product: 526 (4)
# Running Forecast for Product: 527 (8)
# Running Forecast for Product: 528 (2)
# Running Forecast for Product: 529 (8)
# Running Forecast for Product: 530 (8)
# Running Forecast for Product: 531 (4)
# Running Forecast for Product: 532 (8)
# Running Forecast for Product: 533 (1)
# Running Forecast for Product: 534 (4)
# Running Forecast for Product: 535 (5)
# Running Forecast for Product: 536 (4)
# Running Forecast for Product: 537 (4)
# Running Forecast for Product: 538 (4)
# Running Forecast for Product: 539 (5)
# Running Forecast for Product: 540 (4)
# Running Forecast for Product: 541 (5)
# Running Forecast for Product: 542 (4)
# Running Forecast for Product: 543 (4)
# Running Forecast for Product: 544 (4)
# Running Forecast for Product: 545 (2)
# Running Forecast for Product: 546 (4)
# Running Forecast for Product: 547 (9)
# Running Forecast for Product: 548 (4)
# Running Forecast for Product: 549 (8)
# Running Forecast for Product: 550 (4)
# Running Forecast for Product: 551 (8)
# Running Forecast for Product: 552 (6)
# Running Forecast for Product: 553 (1)
# Running Forecast for Product: 554 (3)
# Running Forecast for Product: 555 (9)
# Running Forecast for Product: 556 (1)
# Running Forecast for Product: 557 (9)
# Running Forecast for Product: 558 (5)
# Running Forecast for Product: 559 (6)
# Running Forecast for Product: 560 (6)
# Running Forecast for Product: 561 (4)
# Running Forecast for Product: 562 (4)
# Running Forecast for Product: 563 (6)
# Running Forecast for Product: 564 (8)
# Running Forecast for Product: 565 (4)
# Running Forecast for Product: 566 (4)
# Running Forecast for Product: 567 (1)
# Running Forecast for Product: 568 (6)
# Running Forecast for Product: 569 (1)
# Running Forecast for Product: 570 (2)
# Running Forecast for Product: 571 (4)
# Running Forecast for Product: 572 (1)
# Running Forecast for Product: 573 (4)
# Running Forecast for Product: 574 (8)
# Running Forecast for Product: 575 (8)
# Running Forecast for Product: 576 (9)
# Running Forecast for Product: 577 (4)
# Running Forecast for Product: 578 (4)
# Running Forecast for Product: 579 (3)
# Running Forecast for Product: 580 (3)
# Running Forecast for Product: 581 (9)
# Running Forecast for Product: 582 (4)
# Running Forecast for Product: 583 (7)
# Running Forecast for Product: 584 (9)
# Running Forecast for Product: 585 (5)
# Running Forecast for Product: 586 (3)
# Running Forecast for Product: 587 (9)
# Running Forecast for Product: 588 (2)
# Running Forecast for Product: 589 (9)
# Running Forecast for Product: 590 (4)
# Running Forecast for Product: 591 (5)
# Running Forecast for Product: 592 (1)
# Running Forecast for Product: 593 (4)
# Running Forecast for Product: 594 (4)
# Running Forecast for Product: 595 (4)
# Running Forecast for Product: 596 (1)
# Running Forecast for Product: 597 (1)
# Running Forecast for Product: 598 (4)
# Running Forecast for Product: 599 (4)
# Running Forecast for Product: 600 (1)
# Running Forecast for Product: 601 (4)
# Running Forecast for Product: 602 (3)
# Running Forecast for Product: 603 (8)
# Running Forecast for Product: 604 (8)
# Running Forecast for Product: 605 (8)
# Running Forecast for Product: 606 (1)
# Running Forecast for Product: 607 (3)
# Running Forecast for Product: 608 (3)
# Running Forecast for Product: 609 (1)
# Running Forecast for Product: 610 (8)
# Running Forecast for Product: 611 (1)
# Running Forecast for Product: 612 (3)
# Running Forecast for Product: 613 (3)
# Running Forecast for Product: 614 (9)
# Running Forecast for Product: 615 (8)
# Running Forecast for Product: 616 (2)
# Running Forecast for Product: 617 (9)
# Running Forecast for Product: 618 (6)
# Running Forecast for Product: 619 (3)
# Running Forecast for Product: 620 (2)
# Running Forecast for Product: 621 (3)
# Running Forecast for Product: 622 (4)
# Running Forecast for Product: 623 (6)
# Running Forecast for Product: 624 (1)
# Running Forecast for Product: 625 (9)
# Running Forecast for Product: 626 (4)
# Running Forecast for Product: 627 (4)
# Running Forecast for Product: 628 (4)
# Running Forecast for Product: 629 (3)
# Running Forecast for Product: 630 (6)
# Running Forecast for Product: 631 (2)
# Running Forecast for Product: 632 (9)
# Running Forecast for Product: 633 (1)
# Running Forecast for Product: 634 (8)
# Running Forecast for Product: 635 (5)
# Running Forecast for Product: 636 (3)
# Running Forecast for Product: 637 (1)
# Running Forecast for Product: 638 (4)
# Running Forecast for Product: 639 (9)
# Running Forecast for Product: 640 (3)
# Running Forecast for Product: 641 (4)
# Running Forecast for Product: 642 (4)
# Running Forecast for Product: 643 (2)
# Running Forecast for Product: 644 (7)
# Running Forecast for Product: 645 (4)
# Running Forecast for Product: 646 (2)
# Running Forecast for Product: 647 (1)
# Running Forecast for Product: 648 (5)
# Running Forecast for Product: 649 (7)
# Running Forecast for Product: 650 (9)
# Running Forecast for Product: 651 (9)
# Running Forecast for Product: 652 (4)
# Running Forecast for Product: 653 (9)
# Running Forecast for Product: 654 (1)
# Running Forecast for Product: 655 (9)
# Running Forecast for Product: 656 (1)
# Running Forecast for Product: 657 (3)
# Running Forecast for Product: 658 (8)
# Running Forecast for Product: 659 (8)
# Running Forecast for Product: 660 (4)
# Running Forecast for Product: 661 (4)
# Running Forecast for Product: 662 (5)
# Running Forecast for Product: 663 (2)
# Running Forecast for Product: 664 (4)
# Running Forecast for Product: 665 (4)
# Running Forecast for Product: 666 (4)
# Running Forecast for Product: 667 (8)
# Running Forecast for Product: 668 (4)
# Running Forecast for Product: 669 (4)
# Running Forecast for Product: 670 (4)
# Running Forecast for Product: 671 (3)
# Running Forecast for Product: 672 (4)
# Running Forecast for Product: 673 (3)
# Running Forecast for Product: 674 (1)
# Running Forecast for Product: 675 (8)
# Running Forecast for Product: 676 (4)
# Running Forecast for Product: 677 (4)
# Running Forecast for Product: 678 (2)
# Running Forecast for Product: 679 (1)
# Running Forecast for Product: 680 (5)
#          MAE       Bias model_type   item_id    Sep 2024    Oct 2024  \
# 0  26.194444 -15.821111         BZ    Prod_1   94.881111  123.071111
# 1  23.563744  14.017502         BX   Prod_10   79.996468   70.098747
# 2  80.623271  80.623271         AX  Prod_100  107.337835  107.270681
# 3  11.801990   8.550266         BX  Prod_101  100.322232  116.438954
# 4  53.914388  41.430420         BY  Prod_102  112.838466  122.317906
#
#      Nov 2024            location      region
# 0  109.381111  California - Loc 1  California
# 1  105.904785  California - Loc 1  California
# 2  107.391485  California - Loc 1  California
# 3   81.572148  California - Loc 1  California
# 4  119.843628  California - Loc 1  California

# %%
forecast_results.to_csv(output_results_path, index=False)
